# %%
#Configuracion inicial
#MHHsdD5sGDyTtcWUxqv9
# %matplotlib inline
import matplotlib.pyplot as plt #librería para graficas de python
import numpy # extiende las librerias de matemática de python
import pandas #libreria para procesamiento de datos muy usada en la industria
import seaborn # Extiende las funcionalidades de matplotlib, muy usado en data visualization

# Con esto hacemos los gráficos más grandes, adecuados para el proyector.
seaborn.set_context(context='talk', font_scale=1)

# %%
plt.figure(figsize=(10,10))
#carga util _ Carga ofrecida 
# 09 05 025 023 021 ... 01
plt.plot([1.095,1.95,3.99,5.21,5.8,6.53,7.64,9.89],[1.095,1.95,3.96,4.96,4.98,4.98,4.98,4.98],label="parte 1 caso 1")
plt.plot([1.095,1.95,3.99,4.36,4.73,5.21,5.8,6.53,7.64,9.89],[1.095,1.94,3.96,4.35,4.71,4.96,4.98,4.98,4.98,4.99],label="parte 1 caso 2")
plt.plot([1.095,1.95,3.99,4.36,4.73,5.21,5.8,6.53,7.64,9.89],[1.03,1.59,2.20,2.25,2.30,2.35,2.39,2.43,2.46,2.48],label="parte 2 caso 1")
plt.plot([1.095,1.95,3.99,4.36,4.73,5.21,5.8,6.53,7.64,9.89],[1.03,1.59,2.20,2.25,2.30,2.35,2.39,2.43,2.46,2.48],label="parte 2 caso 2")
plt.plot([1.095,1.95,3.99,4.36,4.73,5.21,5.8,6.53,7.64,9.89],[0.68,0.84,0.93,0.93,0.93,0.94,0.95,0.95,0.95,0.95],label="parte 2.1 caso 1 y caso 2")


plt.axhline(y=5,linestyle=':', xmin=0, xmax=1,color='r',label="network congestion")
plt.xlabel("carga ofrecida (paquetes/s)")
plt.ylabel("carga util (paquetes/s)")
plt.legend()
plt.grid()

# %%
plt.figure(figsize=(10,10))
plt.plot([1.095,1.95,3.99,4.36,4.73,5.21,5.8,6.53,7.64,9.89],[0.42,0.45,0.72,1.02,1.66,5.53,14.69,23.62,28.46,32.87],label="s/n caso 1")
plt.plot([1.095,1.95,3.99,4.36,4.73,5.21,5.8,6.53,7.64,9.89],[0.42,0.45,0.72,1.02,1.66,5.53,14.69,23.62,28.46,32.87],label="s/n caso 2")
plt.plot([1.095,1.95,3.99,4.36,4.73,5.21,5.8,6.53,7.64,9.89],[0.40,0.40,0.40,0.40,0.40,0.40,0.40,0.40,0.40,0.40],label="s/n delay parte 2 caso 1")
plt.plot([1.095,1.95,3.99,4.36,4.73,5.21,5.8,6.53,7.64,9.89],[0.40,0.40,0.40,0.40,0.40,0.40,0.40,0.40,0.40,0.40],label="s/n delay parte 2 caso 2")
plt.plot([1.095,1.95,3.99,4.36,4.73,5.21,5.8,6.53,7.64,9.89],[0.72,0.72,0.70,0.70,0.70,0.70,0.70,0.70,0.70,0.70],label="s/n delay parte 2.1 caso 1 y 2")

plt.xlabel("carga util (paquetes/s)")
plt.ylabel("retardo (s)")
plt.legend()
plt.title("retardo")
# Out:
# Text(0.5, 1.0, 'retardo')

# %%
## Cambiar la dirección del conjunto de datos de acuerdo a dónde lo guardaron
import pandas
data11_01 = pandas.read_csv('11(0.1).csv')
data11_02 = pandas.read_csv('11(0.2).csv')
data11_05 = pandas.read_csv('11(0.5).csv')
data12_01 = pandas.read_csv('12(0.1).csv')
data12_02 = pandas.read_csv('12(0.2).csv')
data12_05 = pandas.read_csv('11(0.5).csv')
data21_01 = pandas.read_csv('21(0.1).csv')
data21_02 = pandas.read_csv('21(0.2).csv')
data21_05 = pandas.read_csv('21(0.5).csv')
data22_01 = pandas.read_csv('22(0.1).csv')
data22_02 = pandas.read_csv('22(0.2).csv')
data22_05 = pandas.read_csv('22(0.5).csv')
data31_01 = pandas.read_csv('31(0.1).csv')
data31_02 = pandas.read_csv('31(0.2).csv')
data31_05 = pandas.read_csv('31(0.5).csv')
data32_01 = pandas.read_csv('32(0.1).csv')
data32_02 = pandas.read_csv('32(0.2).csv')
data32_05 = pandas.read_csv('32(0.5).csv')

# %%
plt.figure(figsize=(30,10))

plt.subplot(1,3,1)
buffer_size_gen = data11_01['vecvalue'].loc[[20]].tolist()
buffer_time_gen = data11_01['vectime'].loc[[20]].tolist()
buffer_size_gen = list(map(float,buffer_size_gen[0].split()))
buffer_time_gen = list(map(float,buffer_time_gen[0].split()))
buffer_size_qeu = data11_01['vecvalue'].loc[[21]].tolist()
buffer_time_qeu = data11_01['vectime'].loc[[21]].tolist()
buffer_size_qeu = list(map(float,buffer_size_qeu[0].split()))
buffer_time_qeu = list(map(float,buffer_time_qeu[0].split()))
buffer_size_sink = data11_01['vecvalue'].loc[[22]].tolist()
buffer_time_sink = data11_01['vectime'].loc[[22]].tolist()
buffer_size_sink = list(map(float,buffer_size_sink[0].split()))
buffer_time_sink = list(map(float,buffer_time_sink[0].split()))


plt.plot(buffer_time_gen,buffer_size_gen,label="gen buffer size")
plt.plot(buffer_time_qeu,buffer_size_qeu,label="qeue buffer size")
plt.plot(buffer_time_sink,buffer_size_sink,label="sink buffer size")
plt.axhline(y=200,linestyle=':', xmin=0, xmax=1,color='r',label="buffer capacity (sink,qeue)")
plt.title("Generation interval 0.1")
plt.xlabel("Segundos")
plt.ylabel("Cantidad de paquetes en el buffer")
plt.grid()
plt.legend()

plt.subplot(1,3,2)
buffer_size_gen = data11_02['vecvalue'].loc[[20]].tolist()
buffer_time_gen = data11_02['vectime'].loc[[20]].tolist()
buffer_size_gen = list(map(float,buffer_size_gen[0].split()))
buffer_time_gen = list(map(float,buffer_time_gen[0].split()))
buffer_size_qeu = data11_02['vecvalue'].loc[[21]].tolist()
buffer_time_qeu = data11_02['vectime'].loc[[21]].tolist()
buffer_size_qeu = list(map(float,buffer_size_qeu[0].split()))
buffer_time_qeu = list(map(float,buffer_time_qeu[0].split()))
buffer_size_sink = data11_02['vecvalue'].loc[[22]].tolist()
buffer_time_sink = data11_02['vectime'].loc[[22]].tolist()
buffer_size_sink = list(map(float,buffer_size_sink[0].split()))
buffer_time_sink = list(map(float,buffer_time_sink[0].split()))

plt.plot(buffer_time_gen,buffer_size_gen,label="gen buffer size")
plt.plot(buffer_time_qeu,buffer_size_qeu,label="qeue buffer size")
plt.plot(buffer_time_sink,buffer_size_sink,label="sink buffer size")
plt.axhline(y=200,linestyle=':', xmin=0, xmax=1,color='r',label="buffer capacity (sink,qeue)")
plt.title("Generation interval 0.2")
plt.xlabel("Segundos")
plt.ylabel("Cantidad de paquetes en el buffer")
plt.grid()
plt.legend()

plt.subplot(1,3,3)
buffer_size_gen = data11_05['vecvalue'].loc[[20]].tolist()
buffer_time_gen = data11_05['vectime'].loc[[20]].tolist()
buffer_size_gen = list(map(float,buffer_size_gen[0].split()))
buffer_time_gen = list(map(float,buffer_time_gen[0].split()))
buffer_size_qeu = data11_05['vecvalue'].loc[[21]].tolist()
buffer_time_qeu = data11_05['vectime'].loc[[21]].tolist()
buffer_size_qeu = list(map(float,buffer_size_qeu[0].split()))
buffer_time_qeu = list(map(float,buffer_time_qeu[0].split()))
buffer_size_sink = data11_05['vecvalue'].loc[[22]].tolist()
buffer_time_sink = data11_05['vectime'].loc[[22]].tolist()
buffer_size_sink = list(map(float,buffer_size_sink[0].split()))
buffer_time_sink = list(map(float,buffer_time_sink[0].split()))

plt.plot(buffer_time_gen,buffer_size_gen,label="gen buffer size")
plt.plot(buffer_time_qeu,buffer_size_qeu,label="qeue buffer size")
plt.plot(buffer_time_sink,buffer_size_sink,label="sink buffer size")
plt.axhline(y=200,linestyle=':', xmin=0, xmax=1,color='r',label="buffer capacity (sink,qeue)")
plt.xlabel("Segundos")
plt.ylabel("Cantidad de paquetes en el buffer")
plt.title("Generation interval 0.5")

plt.grid()
plt.legend()

# %%
plt.figure(figsize=(30,10))

plt.subplot(1,3,1)
plt.ylim(0,50)
delay = data11_01['vecvalue'].loc[[23]].tolist()
delaytime = data11_01['vectime'].loc[[23]].tolist()
delay = list(map(float,delay[0].split()))
delaytime = list(map(float,delaytime[0].split()))
plt.grid()
plt.plot(delaytime,delay,label="delay")
plt.legend()
plt.xlabel("Segundos")
plt.ylabel("Segundos")
plt.title("Generation interval 0.1")

plt.subplot(1,3,2)
plt.ylim(0,50)
delay = data11_02['vecvalue'].loc[[23]].tolist()
delaytime = data11_02['vectime'].loc[[23]].tolist()
delay = list(map(float,delay[0].split()))
delaytime = list(map(float,delaytime[0].split()))
plt.grid()
plt.plot(delaytime,delay,label="delay")
plt.legend()
plt.xlabel("Segundos")
plt.ylabel("Segundos")
plt.title("Generation interval 0.2")

plt.subplot(1,3,3)
plt.ylim(0,50)
delay = data11_05['vecvalue'].loc[[23]].tolist()
delaytime = data11_05['vectime'].loc[[23]].tolist()
delay = list(map(float,delay[0].split()))
delaytime = list(map(float,delaytime[0].split()))
plt.grid()
plt.plot(delaytime,delay,label="delay")
plt.legend()
plt.xlabel("Segundos")
plt.ylabel("Segundos")
plt.title("Generation interval 0.5")
# Out:
# Text(0.5, 1.0, 'Generation interval 0.5')

# %%
plt.figure(figsize=(30,10))
plt.grid()

plt.subplot(1,3,1)
buffer_size_gen = data12_01['vecvalue'].loc[[20]].tolist()
buffer_time_gen = data12_01['vectime'].loc[[20]].tolist()
buffer_size_gen = list(map(float,buffer_size_gen[0].split()))
buffer_time_gen = list(map(float,buffer_time_gen[0].split()))
buffer_size_qeu = data12_01['vecvalue'].loc[[21]].tolist()
buffer_time_qeu = data12_01['vectime'].loc[[21]].tolist()
buffer_size_qeu = list(map(float,buffer_size_qeu[0].split()))
buffer_time_qeu = list(map(float,buffer_time_qeu[0].split()))
buffer_size_sink = data12_01['vecvalue'].loc[[22]].tolist()
buffer_time_sink = data12_01['vectime'].loc[[22]].tolist()
buffer_size_sink = list(map(float,buffer_size_sink[0].split()))
buffer_time_sink = list(map(float,buffer_time_sink[0].split()))


plt.plot(buffer_time_gen,buffer_size_gen,label="gen buffer size")
plt.plot(buffer_time_qeu,buffer_size_qeu,label="qeue buffer size")
plt.plot(buffer_time_sink,buffer_size_sink,label="sink buffer size")
plt.axhline(y=200,linestyle=':', xmin=0, xmax=1,color='r',label="buffer capacity (sink,qeue)")
plt.title("Generation interval 0.1")
plt.xlabel("Segundos")
plt.ylabel("Cantidad de paquetes en el buffer")
plt.grid()
plt.legend()

plt.subplot(1,3,2)
buffer_size_gen = data12_02['vecvalue'].loc[[20]].tolist()
buffer_time_gen = data12_02['vectime'].loc[[20]].tolist()
buffer_size_gen = list(map(float,buffer_size_gen[0].split()))
buffer_time_gen = list(map(float,buffer_time_gen[0].split()))
buffer_size_qeu = data12_02['vecvalue'].loc[[21]].tolist()
buffer_time_qeu = data12_02['vectime'].loc[[21]].tolist()
buffer_size_qeu = list(map(float,buffer_size_qeu[0].split()))
buffer_time_qeu = list(map(float,buffer_time_qeu[0].split()))
buffer_size_sink = data12_02['vecvalue'].loc[[22]].tolist()
buffer_time_sink = data12_02['vectime'].loc[[22]].tolist()
buffer_size_sink = list(map(float,buffer_size_sink[0].split()))
buffer_time_sink = list(map(float,buffer_time_sink[0].split()))

plt.plot(buffer_time_gen,buffer_size_gen,label="gen buffer size")
plt.plot(buffer_time_qeu,buffer_size_qeu,label="qeue buffer size")
plt.plot(buffer_time_sink,buffer_size_sink,label="sink buffer size")
plt.axhline(y=200,linestyle=':', xmin=0, xmax=1,color='r',label="buffer capacity (sink,qeue)")
plt.title("Generation interval 0.2")
plt.xlabel("Segundos")
plt.ylabel("Cantidad de paquetes en el buffer")
plt.grid()
plt.legend()

plt.subplot(1,3,3)
buffer_size_gen = data12_05['vecvalue'].loc[[20]].tolist()
buffer_time_gen = data12_05['vectime'].loc[[20]].tolist()
buffer_size_gen = list(map(float,buffer_size_gen[0].split()))
buffer_time_gen = list(map(float,buffer_time_gen[0].split()))
buffer_size_qeu = data12_05['vecvalue'].loc[[21]].tolist()
buffer_time_qeu = data12_05['vectime'].loc[[21]].tolist()
buffer_size_qeu = list(map(float,buffer_size_qeu[0].split()))
buffer_time_qeu = list(map(float,buffer_time_qeu[0].split()))
buffer_size_sink = data12_05['vecvalue'].loc[[22]].tolist()
buffer_time_sink = data12_05['vectime'].loc[[22]].tolist()
buffer_size_sink = list(map(float,buffer_size_sink[0].split()))
buffer_time_sink = list(map(float,buffer_time_sink[0].split()))

plt.plot(buffer_time_gen,buffer_size_gen,label="gen buffer size")
plt.plot(buffer_time_qeu,buffer_size_qeu,label="qeue buffer size")
plt.plot(buffer_time_sink,buffer_size_sink,label="sink buffer size")
plt.axhline(y=200,linestyle=':', xmin=0, xmax=1,color='r',label="buffer capacity (sink,qeue)")
plt.title("Generation interval 0.5")
plt.xlabel("Segundos")
plt.ylabel("Cantidad de paquetes en el buffer")
plt.grid()
plt.legend()

# %%
plt.figure(figsize=(30,10))

plt.subplot(1,3,1)
plt.ylim(0,50)
delay = data12_01['vecvalue'].loc[[23]].tolist()
delaytime = data12_01['vectime'].loc[[23]].tolist()
delay = list(map(float,delay[0].split()))
delaytime = list(map(float,delaytime[0].split()))
plt.grid()
plt.plot(delaytime,delay,label="delay")
plt.legend()
plt.xlabel("Segundos")
plt.ylabel("Segundos")
plt.title("Generation interval 0.1")

plt.subplot(1,3,2)
plt.ylim(0,50)
delay = data12_02['vecvalue'].loc[[23]].tolist()
delaytime = data12_02['vectime'].loc[[23]].tolist()
delay = list(map(float,delay[0].split()))
delaytime = list(map(float,delaytime[0].split()))
plt.grid()
plt.plot(delaytime,delay,label="delay")
plt.legend()
plt.xlabel("Segundos")
plt.ylabel("Segundos")
plt.title("Generation interval 0.2")

plt.subplot(1,3,3)
plt.ylim(0,50)
delay = data12_05['vecvalue'].loc[[23]].tolist()
delaytime = data12_05['vectime'].loc[[23]].tolist()
delay = list(map(float,delay[0].split()))
delaytime = list(map(float,delaytime[0].split()))
plt.grid()
plt.plot(delaytime,delay,label="delay")
plt.legend()
plt.xlabel("Segundos")
plt.ylabel("Segundos")
plt.title("Generation interval 0.2")
# Out:
# Text(0.5, 1.0, 'Generation interval 0.2')

# %%
plt.figure(figsize=(30,15))

buffer_size_gen = data21_01['vecvalue'].loc[[21]].tolist()
buffer_time_gen = data21_01['vectime'].loc[[21]].tolist()
buffer_size_gen = list(map(float,buffer_size_gen[0].split()))
buffer_time_gen = list(map(float,buffer_time_gen[0].split()))
buffer_size_qeu = data21_01['vecvalue'].loc[[22]].tolist()
buffer_time_qeu = data21_01['vectime'].loc[[22]].tolist()
buffer_size_qeu = list(map(float,buffer_size_qeu[0].split()))
buffer_time_qeu = list(map(float,buffer_time_qeu[0].split()))
buffer_size_sink = data21_01['vecvalue'].loc[[23]].tolist()
buffer_time_sink = data21_01['vectime'].loc[[23]].tolist()
buffer_size_sink = list(map(float,buffer_size_sink[0].split()))
buffer_time_sink = list(map(float,buffer_time_sink[0].split()))

plt.subplot(3,3,1)
plt.plot(buffer_time_gen,buffer_size_gen,label="gen buffer size")
plt.grid()
plt.title("Generation interval 0.1")
plt.legend()
plt.subplot(3,3,4)
plt.plot(buffer_time_qeu,buffer_size_qeu,label="qeue buffer size")
plt.grid()
plt.legend()
plt.subplot(3,3,7)
plt.plot(buffer_time_sink,buffer_size_sink,label="sink buffer size")
plt.grid()
plt.legend()
plt.xlabel("Segundos")
plt.ylabel("Cantidad de paquetes en el buffer")

buffer_size_gen = data21_02['vecvalue'].loc[[21]].tolist()
buffer_time_gen = data21_02['vectime'].loc[[21]].tolist()
buffer_size_gen = list(map(float,buffer_size_gen[0].split()))
buffer_time_gen = list(map(float,buffer_time_gen[0].split()))
buffer_size_qeu = data21_02['vecvalue'].loc[[22]].tolist()
buffer_time_qeu = data21_02['vectime'].loc[[22]].tolist()
buffer_size_qeu = list(map(float,buffer_size_qeu[0].split()))
buffer_time_qeu = list(map(float,buffer_time_qeu[0].split()))
buffer_size_sink = data21_02['vecvalue'].loc[[23]].tolist()
buffer_time_sink = data21_02['vectime'].loc[[23]].tolist()
buffer_size_sink = list(map(float,buffer_size_sink[0].split()))
buffer_time_sink = list(map(float,buffer_time_sink[0].split()))

plt.subplot(3,3,2)
plt.plot(buffer_time_gen,buffer_size_gen,label="gen buffer size")
plt.grid()
plt.title("Generation interval 0.2")
plt.legend()
plt.subplot(3,3,5)
plt.plot(buffer_time_qeu,buffer_size_qeu,label="qeue buffer size")
plt.grid()
plt.legend()
plt.subplot(3,3,8)
plt.plot(buffer_time_sink,buffer_size_sink,label="sink buffer size")
plt.grid()
plt.legend()

buffer_size_gen = data21_05['vecvalue'].loc[[21]].tolist()
buffer_time_gen = data21_05['vectime'].loc[[21]].tolist()
buffer_size_gen = list(map(float,buffer_size_gen[0].split()))
buffer_time_gen = list(map(float,buffer_time_gen[0].split()))
buffer_size_qeu = data21_05['vecvalue'].loc[[22]].tolist()
buffer_time_qeu = data21_05['vectime'].loc[[22]].tolist()
buffer_size_qeu = list(map(float,buffer_size_qeu[0].split()))
buffer_time_qeu = list(map(float,buffer_time_qeu[0].split()))
buffer_size_sink = data21_05['vecvalue'].loc[[23]].tolist()
buffer_time_sink = data21_05['vectime'].loc[[23]].tolist()
buffer_size_sink = list(map(float,buffer_size_sink[0].split()))
buffer_time_sink = list(map(float,buffer_time_sink[0].split()))

plt.subplot(3,3,3)
plt.plot(buffer_time_gen,buffer_size_gen,label="gen buffer size")
plt.grid()
plt.title("Generation interval 0.5")
plt.legend()
plt.subplot(3,3,6)
plt.plot(buffer_time_qeu,buffer_size_qeu,label="qeue buffer size")
plt.grid()
plt.legend()
plt.subplot(3,3,9)
plt.plot(buffer_time_sink,buffer_size_sink,label="sink buffer size")
plt.grid()
plt.legend()

# %%
plt.figure(figsize=(30,10))

plt.subplot(1,3,1)
delay = data21_01['vecvalue'].loc[[24]].tolist()
delaytime = data21_01['vectime'].loc[[24]].tolist()
delay = list(map(float,delay[0].split()))
delaytime = list(map(float,delaytime[0].split()))
plt.grid()
plt.plot(delaytime,delay,label="delay")
plt.legend()
plt.title("Generation interval 0.1")
plt.xlabel("Segundos")
plt.ylabel("Segundos")

plt.subplot(1,3,2)
delay = data21_02['vecvalue'].loc[[24]].tolist()
delaytime = data21_02['vectime'].loc[[24]].tolist()
delay = list(map(float,delay[0].split()))
delaytime = list(map(float,delaytime[0].split()))
plt.grid()
plt.plot(delaytime,delay,label="delay")
plt.legend()
plt.title("Generation interval 0.2")

plt.subplot(1,3,3)
delay = data21_05['vecvalue'].loc[[24]].tolist()
delaytime = data21_05['vectime'].loc[[24]].tolist()
delay = list(map(float,delay[0].split()))
delaytime = list(map(float,delaytime[0].split()))
plt.grid()
plt.plot(delaytime,delay,label="delay")
plt.legend()
plt.title("Generation interval 0.5")
# Out:
# Text(0.5, 1.0, 'Generation interval 0.5')

# %%
plt.figure(figsize=(30,15))

buffer_size_gen = data22_01['vecvalue'].loc[[21]].tolist()
buffer_time_gen = data22_01['vectime'].loc[[21]].tolist()
buffer_size_gen = list(map(float,buffer_size_gen[0].split()))
buffer_time_gen = list(map(float,buffer_time_gen[0].split()))
buffer_size_qeu = data22_01['vecvalue'].loc[[22]].tolist()
buffer_time_qeu = data22_01['vectime'].loc[[22]].tolist()
buffer_size_qeu = list(map(float,buffer_size_qeu[0].split()))
buffer_time_qeu = list(map(float,buffer_time_qeu[0].split()))
buffer_size_sink = data22_01['vecvalue'].loc[[23]].tolist()
buffer_time_sink = data22_01['vectime'].loc[[23]].tolist()
buffer_size_sink = list(map(float,buffer_size_sink[0].split()))
buffer_time_sink = list(map(float,buffer_time_sink[0].split()))

plt.subplot(3,3,1)
plt.plot(buffer_time_gen,buffer_size_gen,label="gen buffer size")
plt.grid()
plt.title("0.1")
plt.legend()
plt.subplot(3,3,4)
plt.plot(buffer_time_qeu,buffer_size_qeu,label="qeue buffer size")
plt.grid()
plt.legend()
plt.subplot(3,3,7)
plt.plot(buffer_time_sink,buffer_size_sink,label="sink buffer size")
plt.grid()
plt.legend()

buffer_size_gen = data22_02['vecvalue'].loc[[21]].tolist()
buffer_time_gen = data22_02['vectime'].loc[[21]].tolist()
buffer_size_gen = list(map(float,buffer_size_gen[0].split()))
buffer_time_gen = list(map(float,buffer_time_gen[0].split()))
buffer_size_qeu = data22_02['vecvalue'].loc[[22]].tolist()
buffer_time_qeu = data22_02['vectime'].loc[[22]].tolist()
buffer_size_qeu = list(map(float,buffer_size_qeu[0].split()))
buffer_time_qeu = list(map(float,buffer_time_qeu[0].split()))
buffer_size_sink = data22_02['vecvalue'].loc[[23]].tolist()
buffer_time_sink = data22_02['vectime'].loc[[23]].tolist()
buffer_size_sink = list(map(float,buffer_size_sink[0].split()))
buffer_time_sink = list(map(float,buffer_time_sink[0].split()))

plt.subplot(3,3,2)
plt.plot(buffer_time_gen,buffer_size_gen,label="gen buffer size")
plt.grid()
plt.title("0.2")
plt.legend()
plt.subplot(3,3,5)
plt.plot(buffer_time_qeu,buffer_size_qeu,label="qeue buffer size")
plt.grid()
plt.legend()
plt.subplot(3,3,8)
plt.plot(buffer_time_sink,buffer_size_sink,label="sink buffer size")
plt.grid()
plt.legend()

buffer_size_gen = data22_05['vecvalue'].loc[[21]].tolist()
buffer_time_gen = data22_05['vectime'].loc[[21]].tolist()
buffer_size_gen = list(map(float,buffer_size_gen[0].split()))
buffer_time_gen = list(map(float,buffer_time_gen[0].split()))
buffer_size_qeu = data22_05['vecvalue'].loc[[22]].tolist()
buffer_time_qeu = data22_05['vectime'].loc[[22]].tolist()
buffer_size_qeu = list(map(float,buffer_size_qeu[0].split()))
buffer_time_qeu = list(map(float,buffer_time_qeu[0].split()))
buffer_size_sink = data22_05['vecvalue'].loc[[23]].tolist()
buffer_time_sink = data22_05['vectime'].loc[[23]].tolist()
buffer_size_sink = list(map(float,buffer_size_sink[0].split()))
buffer_time_sink = list(map(float,buffer_time_sink[0].split()))

plt.subplot(3,3,3)
plt.plot(buffer_time_gen,buffer_size_gen,label="gen buffer size")
plt.grid()
plt.title("0.5")
plt.legend()
plt.subplot(3,3,6)
plt.plot(buffer_time_qeu,buffer_size_qeu,label="qeue buffer size")
plt.grid()
plt.legend()
plt.subplot(3,3,9)
plt.plot(buffer_time_sink,buffer_size_sink,label="sink buffer size")
plt.grid()
plt.legend()

# %%
#@title
plt.figure(figsize=(30,10))

plt.subplot(1,3,1)
delay = data22_01['vecvalue'].loc[[24]].tolist()
delaytime = data22_01['vectime'].loc[[24]].tolist()
delay = list(map(float,delay[0].split()))
delaytime = list(map(float,delaytime[0].split()))
plt.grid()
plt.plot(delaytime,delay,label="delay")
plt.legend()
plt.title("Generation interval 0.1")
plt.xlabel("Segundos")
plt.ylabel("Segundos")

plt.subplot(1,3,2)
delay = data22_02['vecvalue'].loc[[24]].tolist()
delaytime = data22_02['vectime'].loc[[24]].tolist()
delay = list(map(float,delay[0].split()))
delaytime = list(map(float,delaytime[0].split()))
plt.grid()
plt.plot(delaytime,delay,label="delay")
plt.legend()
plt.title("Generation interval 0.2")

plt.subplot(1,3,3)
delay = data22_05['vecvalue'].loc[[24]].tolist()
delaytime = data22_05['vectime'].loc[[24]].tolist()
delay = list(map(float,delay[0].split()))
delaytime = list(map(float,delaytime[0].split()))
plt.grid()
plt.plot(delaytime,delay,label="delay")
plt.legend()
plt.title("Generation interval 0.5")
# Out:
# Text(0.5, 1.0, 'Generation interval 0.5')

# %%
##caso en el que se pierden paquetes por alguna razon que no sea congestion de red

# %%
plt.figure(figsize=(30,10))

plt.subplot(1,3,1)
delay = data31_01['vecvalue'].loc[[24]].tolist()
delaytime = data31_01['vectime'].loc[[24]].tolist()
delay = list(map(float,delay[0].split()))
delaytime = list(map(float,delaytime[0].split()))
plt.grid()
plt.plot(delaytime,delay,label="delay")
plt.legend()
plt.xlabel("Segundos")
plt.ylabel("Segundos")
plt.title("Generation interval 0.1")

plt.subplot(1,3,2)
delay = data31_02['vecvalue'].loc[[24]].tolist()
delaytime = data31_02['vectime'].loc[[24]].tolist()
delay = list(map(float,delay[0].split()))
delaytime = list(map(float,delaytime[0].split()))
plt.grid()
plt.plot(delaytime,delay,label="delay")
plt.legend()
plt.xlabel("Segundos")
plt.ylabel("Segundos")
plt.title("Generation interval 0.2")

plt.subplot(1,3,3)
delay = data31_02['vecvalue'].loc[[24]].tolist()
delaytime = data31_02['vectime'].loc[[24]].tolist()
delay = list(map(float,delay[0].split()))
delaytime = list(map(float,delaytime[0].split()))
plt.grid()
plt.plot(delaytime,delay,label="delay")
plt.legend()
plt.xlabel("Segundos")
plt.ylabel("Segundos")
plt.title("Generation interval 0.5")
# Out:
# Text(0.5, 1.0, 'Generation interval 0.5')
